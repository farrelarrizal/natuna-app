# %%
import pandas as pd

# %%
import pysd

# Load the Vensim model
model = pysd.read_vensim('scenario_ditoooooo.mdl')
model.doc
# Out:
#                                          Real Name  \
# 0             "Block D-Alpha Natural Gas Reserves"
# 1    "Initial Value of Block D-Alpha Gas Reserves"
# 2                 "Non-Tax Indonesia State Income"
# 3                            "State Revenue (Tax)"
# 4                    Age of Reef and Deep Sea Fish
# ..                                             ...
# 214                                    Unit Deploy
# 215             Utilization of Gas within the area
# 216             Utilization of Oil within the area
# 217                              Warships Strength
# 218                              Workforce Quality
#
#                                         Py Name Subscripts              Units  \
# 0             block_dalpha_natural_gas_reserves       None                TCF
# 1    initial_value_of_block_dalpha_gas_reserves       None                TCF
# 2                 nontax_indonesia_state_income       None  Rupiah/Percentage
# ...

# %%
result = model.run()
result
# Out:
#       FINAL TIME  INITIAL TIME  SAVEPER  TIME STEP  Workforce Quality  \
# time
# 1            132             1        1          1           4.772604
# 2            132             1        1          1           2.891732
# 3            132             1        1          1           3.241201
# 4            132             1        1          1           4.361161
# 5            132             1        1          1           1.789682
# ...          ...           ...      ...        ...                ...
# 128          132             1        1          1           3.388187
# 129          132             1        1          1           1.977629
# 130          132             1        1          1           4.690266
# 131          132             1        1          1           3.679169
# 132          132             1        1          1           3.751443
#
#      Effect of Billateral Cooperation  Military Impact  \
# time
# 1                                   0        60.000000
# ...

# %%
result.to_excel('output.xlsx')
